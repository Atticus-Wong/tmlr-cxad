# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://github.com/hate-alert/HateXplain/raw/master/Data/dataset.json
# !wget https://github.com/hate-alert/HateXplain/raw/master/Data/post_id_divisions.json

# !cp dataset.json /content/drive/MyDrive/Explanation_XAI/HateXPlain/dataset.json
# !cp post_id_divisions.json /content/drive/MyDrive/Explanation_XAI/HateXPlain/post_id_divisions.json
# Out:
# --2024-01-23 10:13:41--  https://github.com/hate-alert/HateXplain/raw/master/Data/dataset.json
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hate-alert/HateXplain/master/Data/dataset.json [following]
# --2024-01-23 10:13:41--  https://raw.githubusercontent.com/hate-alert/HateXplain/master/Data/dataset.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12256170 (12M) [text/plain]
# Saving to: ‘dataset.json.1’
#
# dataset.json.1      100%[===================>]  11.69M  --.-KB/s    in 0.04s
#
# 2024-01-23 10:13:41 (283 MB/s) - ‘dataset.json.1’ saved [12256170/12256170]
#
# ...

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import json

porter = PorterStemmer()

nltk.download('stopwords')
nltk.download('wordnet')
stopword_set = set(stopwords.words('english'))
lemma = nltk.wordnet.WordNetLemmatizer()

dataset_raw = open('dataset.json')
ids_raw = open('post_id_divisions.json')
ids = json.load(ids_raw)
dataset = json.load(dataset_raw)

ids_concat = ids['test'] + ids['train'] + ids['val']
count = 0

tokens = set()
for post_id in ids_concat:
    post = dataset[post_id]
    for token in post['post_tokens']:
        if token in stopword_set:
            continue
        token_stem = porter.stem(token)
        if not token_stem in tokens:
            if count < 40:
                print(token_stem)
                count += 1
        tokens.add(token_stem)

tokens_list = list(tokens)
tokens_list.sort()
print('tokens_len: {}'.format(len(tokens)))
tokens_dir = '/content/drive/MyDrive/Explanation_XAI/HateXPlain/tokens.json'
with open(tokens_dir, 'w') as f:
    json.dump(tokens_list, f)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# <user>
# men
# rape
# abus
# call
# violenc
# women
# children
# alway
# perpetr
# come
# first
# even
# miss
# essenti
# premis
# whether
# immigr
# commit
# crime
# dumbass
# repeat
# littl
# retard
# well
# ’
# muslim
# cours
# hate
# jew
# hatr
# one
# defin
# featur
# islam
# lol
# deal
# bm
# outsid
# ss
# tokens_len: 20172
